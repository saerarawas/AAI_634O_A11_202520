# %% [markdown]
# <a href="https://colab.research.google.com/github/saerarawas/AAI_634O_A11_202520/blob/main/Project/Final_Project_Rawas_Saera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dash
import dash
from dash import dcc, html
import pandas as pd
import plotly.express as px

# Load sales data from CSV
url = 'https://raw.githubusercontent.com/DrManalJalloul/Introduction-to-Data-Engineering/main/sales_data.csv'
df = pd.read_csv(url, parse_dates=['date'])

# Aggregate sales data by store location
total_sales_by_location = df.groupby('store_location')['sales_amount'].sum().reset_index()

# Initialize Dash App
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Sales Dashboard"),

    # Total sales by store location
    dcc.Graph(
        id='sales-by-location',
        figure=px.bar(
            total_sales_by_location,
            x='store_location',
            y='sales_amount',
            title='Total Sales by Store Location'
        )
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import pandas as pd

# URL to the CSV file
url = 'https://raw.githubusercontent.com/DrManalJalloul/Introduction-to-Data-Engineering/main/sales_data.csv'

# Load data from the URL
sales_data = pd.read_csv(url)

# Display the first few rows of the DataFrame
print("CSV file loaded successfully!")
sales_data.head()
# Out:
# CSV file loaded successfully!
#          date product_id  sales_amount store_location
# 0  2025-02-05       P001           150       New York
# 1  2025-02-05       P002           300    Los Angeles
# 2  2025-02-05       P003           450        Chicago
# 3  2025-02-05       P004           600        Houston
# 4  2025-02-05       P005           750        Seattle

# %%
def fetch_weather_data(city, date, api_key):
    base_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}"
    response = requests.get(base_url)
    #print(response)
    data = response.json()
    #print(data)
    # Extract temperature, humidity, and weather description
    temperature = data['main']['temp'] - 273.15 # Convert from Kelvin to Celsius
    humidity = data['main']['humidity']
    weather_description = data['weather'][0]['description']
    return temperature, humidity, weather_description

# %%
import requests

def fetch_weather_data(city, date, api_key):
    base_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}"
    response = requests.get(base_url)

    # Print the entire response for debugging purposes
    print(response.json())

    data = response.json()

    # Check if the 'main' key is in the response
    if 'main' in data:
        temperature = data['main']['temp'] - 273.15  # Convert from Kelvin to Celsius
        humidity = data['main']['humidity']
        weather_description = data['weather'][0]['description']
        return temperature, humidity, weather_description
    else:
        # Handle the case where 'main' key is not found
        print("Error: 'main' key not found in the response.")
        return None, None, None

# Example usage
api_key = "3159ae9ae876db0990fa9835fbc288dc"
#api_key = "8324bcc3c6e36168d126a13e9d9de7f3"
temp, humidity, description = fetch_weather_data('New York', '2025-02-02', api_key)
if temp is not None:
    print(f"Temp: {temp:.2f}°C, Humidity: {humidity}%, Weather: {description}")
else:
    print("Failed to retrieve weather data.")
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 273.8, 'feels_like': 273.8, 'temp_min': 271.59, 'temp_max': 274.81, 'pressure': 1026, 'humidity': 67, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 302, 'gust': 2.68}, 'clouds': {'all': 20}, 'dt': 1739167845, 'sys': {'type': 2, 'id': 2008776, 'country': 'US', 'sunrise': 1739188566, 'sunset': 1739226274}, 'timezone': -18000, 'id': 5128581, 'name': 'New York', 'cod': 200}
# Temp: 0.65°C, Humidity: 67%, Weather: few clouds

# %%
# Loop through each row of the sales_data dataframe, call the function and update the dataframe with weather data
for index, row in sales_data.iterrows():
    temp, humidity, description = fetch_weather_data(row["store_location"], row["date"],api_key)
    sales_data.at[index, "Temperature (°C)"] = temp
    sales_data.at[index, "Humidity (%)"] = humidity
    sales_data.at[index, "Weather Description"] = description
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 273.8, 'feels_like': 273.8, 'temp_min': 271.59, 'temp_max': 274.81, 'pressure': 1026, 'humidity': 67, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 302, 'gust': 2.68}, 'clouds': {'all': 20}, 'dt': 1739167845, 'sys': {'type': 2, 'id': 2008776, 'country': 'US', 'sunrise': 1739188566, 'sunset': 1739226274}, 'timezone': -18000, 'id': 5128581, 'name': 'New York', 'cod': 200}
# ...

# %%
sales_data
# Out:
#           date product_id  sales_amount store_location  Temperature (°C)  \
# 0   2025-02-05       P001           150       New York              0.93
# 1   2025-02-05       P002           300    Los Angeles             12.73
# 2   2025-02-05       P003           450        Chicago             -4.96
# 3   2025-02-05       P004           600        Houston             20.50
# 4   2025-02-05       P005           750        Seattle              1.51
# 5   2025-02-05       P001           900       New York              0.93
# 6   2025-02-05       P002           950    Los Angeles             12.73
# 7   2025-02-06       P001           150       New York              0.93
# 8   2025-02-06       P002           300    Los Angeles             12.73
# 9   2025-02-06       P003           450        Chicago             -4.96
# 10  2025-02-06       P004           600        Houston             20.50
# 11  2025-02-06       P005           750        Seattle              1.51
# ...

# %%
# !pip install pymongo
from pymongo import MongoClient
from datetime import datetime


connection_string="mongodb+srv://tsjannoun123:KufyyNNqnno0atX9@cluster0.sb8py.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Connect to the MongoDB Atlas cluster
client = MongoClient(connection_string)

# Access a specific database
db = client['weather']

# %%
# Access a the collection sales within the database
sales = db['sales']

#Load the sales data

# Convert DataFrame to dictionary format
sales_dict = sales_data.to_dict(orient="records")

# Insert the sales data into MongoDB
sales.insert_many(sales_dict)
# Out:
# InsertManyResult([ObjectId('67a999ed323fa86e7ce17cc2'), ObjectId('67a999ed323fa86e7ce17cc3'), ObjectId('67a999ed323fa86e7ce17cc4'), ObjectId('67a999ed323fa86e7ce17cc5'), ObjectId('67a999ed323fa86e7ce17cc6'), ObjectId('67a999ed323fa86e7ce17cc7'), ObjectId('67a999ed323fa86e7ce17cc8'), ObjectId('67a999ed323fa86e7ce17cc9'), ObjectId('67a999ed323fa86e7ce17cca'), ObjectId('67a999ed323fa86e7ce17ccb'), ObjectId('67a999ed323fa86e7ce17ccc'), ObjectId('67a999ed323fa86e7ce17ccd'), ObjectId('67a999ed323fa86e7ce17cce'), ObjectId('67a999ed323fa86e7ce17ccf'), ObjectId('67a999ed323fa86e7ce17cd0'), ObjectId('67a999ed323fa86e7ce17cd1'), ObjectId('67a999ed323fa86e7ce17cd2'), ObjectId('67a999ed323fa86e7ce17cd3'), ObjectId('67a999ed323fa86e7ce17cd4'), ObjectId('67a999ed323fa86e7ce17cd5'), ObjectId('67a999ed323fa86e7ce17cd6'), ObjectId('67a999ed323fa86e7ce17cd7'), ObjectId('67a999ed323fa86e7ce17cd8'), ObjectId('67a999ed323fa86e7ce17cd9'), ObjectId('67a999ed323fa86e7ce17cda'), ObjectId('67a999ed323fa86e7ce1
# ...

# %%
# Insert some data
sales.insert_one({
    "store_location": "Seattle",
    "date": "2025-02-12",
    "sales_amount": 2300,
    "Temperature (°C)": 10,
    "Humidity (%)": 65,
    "Weather Description": "Partly Cloudy"
})

# Query by location
print("Sales in New York:")
for record in sales.find({"store_location": "New York"}):
    print(record)

# Update a record
sales.update_one(
    {"store_location": "Seattle", "date": "2025-02-12"},
    {"$set": {"sales_amount": 2400}}
)

# Delete a record
sales.delete_one({"store_location": "Chicago", "date": "2025-02-11"})

# Query to confirm changes
print("\nUpdated Sales in Seattle:")
for record in sales.find({"store_location": "Seattle"}):
    print(record)
# Out:
# Sales in New York:
# {'_id': ObjectId('67a8735e20b106593ac3b028'), 'date': '2025-02-05', 'product_id': 'P001', 'sales_amount': 150, 'store_location': 'New York', 'Temperature (°C)': 0.4399999999999977, 'Humidity (%)': 93.0, 'Weather Description': 'light rain'}
# {'_id': ObjectId('67a8735e20b106593ac3b02d'), 'date': '2025-02-05', 'product_id': 'P001', 'sales_amount': 900, 'store_location': 'New York', 'Temperature (°C)': 0.4399999999999977, 'Humidity (%)': 93.0, 'Weather Description': 'light rain'}
# {'_id': ObjectId('67a8735e20b106593ac3b02f'), 'date': '2025-02-06', 'product_id': 'P001', 'sales_amount': 150, 'store_location': 'New York', 'Temperature (°C)': 0.4399999999999977, 'Humidity (%)': 93.0, 'Weather Description': 'light rain'}
# {'_id': ObjectId('67a8735e20b106593ac3b034'), 'date': '2025-02-06', 'product_id': 'P001', 'sales_amount': 900, 'store_location': 'New York', 'Temperature (°C)': 0.4399999999999977, 'Humidity (%)': 93.0, 'Weather Description': 'light rain'}
# ...

# %%
import pandas as pd
from pymongo import MongoClient
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

# MongoDB connection setup
connection_string = "mongodb+srv://tsjannoun123:KufyyNNqnno0atX9@cluster0.sb8py.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(connection_string)
db = client['weather']
sales = db['sales']

# Query data from MongoDB
sales_data = pd.DataFrame(list(sales.find()))

# Preprocess the data (e.g., convert date to datetime type)
sales_data['date'] = pd.to_datetime(sales_data['date'])

# Check the first few rows of the data
print(sales_data.head())
# Out:
#                         _id       date product_id  sales_amount  \
# 0  67a8735e20b106593ac3b028 2025-02-05       P001           150
# 1  67a8735e20b106593ac3b029 2025-02-05       P002           300
# 2  67a8735e20b106593ac3b02a 2025-02-05       P003           450
# 3  67a8735e20b106593ac3b02b 2025-02-05       P004           600
# 4  67a8735e20b106593ac3b02c 2025-02-05       P005           750
#
#   store_location  Temperature (°C)  Humidity (%) Weather Description
# 0       New York              0.44          93.0          light rain
# 1    Los Angeles             10.80          82.0           clear sky
# 2        Chicago             -2.28          79.0     overcast clouds
# 3        Houston             22.13          88.0       broken clouds
# 4        Seattle              1.68          92.0                mist

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

# App layout with a title and a graph for visualization
app.layout = html.Div(children=[
    html.H1("Sales Data Visualization"),

    # Dropdown to select store location
    dcc.Dropdown(
        id='store-location-dropdown',
        options=[{'label': location, 'value': location} for location in sales_data['store_location'].unique()],
        value='New York',  # Default value
        style={'width': '50%'}
    ),

    # Graph for visualizing sales over time
    dcc.Graph(id='sales-over-time'),

    # Graph for weather vs sales comparison
    dcc.Graph(id='weather-vs-sales')
])

# Callback to update sales over time graph based on selected location
@app.callback(
    Output('sales-over-time', 'figure'),
    Input('store-location-dropdown', 'value')
)
def update_sales_over_time(selected_location):
    filtered_data = sales_data[sales_data['store_location'] == selected_location]

    # Create a line plot of sales over time
    fig = px.line(filtered_data, x='date', y='sales_amount',
                  title=f'Sales Over Time for {selected_location}',
                  labels={'sales_amount': 'Sales Amount ($)', 'date': 'Date'})

    return fig

# Callback to update weather vs sales graph based on selected location
@app.callback(
    Output('weather-vs-sales', 'figure'),
    Input('store-location-dropdown', 'value')
)
def update_weather_vs_sales(selected_location):
    filtered_data = sales_data[sales_data['store_location'] == selected_location]

    # Create a scatter plot comparing sales amount and temperature
    fig = px.scatter(filtered_data, x='Temperature (°C)', y='sales_amount',
                     title=f'Weather vs Sales for {selected_location}',
                     labels={'sales_amount': 'Sales Amount ($)', 'Temperature (°C)': 'Temperature (°C)'})

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# !pip install dash-bootstrap-components
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
from pymongo import MongoClient

# MongoDB Connection
client = MongoClient("mongodb+srv://tsjannoun123:KufyyNNqnno0atX9@cluster0.sb8py.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client["Sales_Weather_DAG"]
collection = db["Sales_Weather"]

# Query the data from MongoDB
data = list(collection.find())

# Convert the data to a Pandas DataFrame
df = pd.DataFrame(data)

# Ensure 'date' is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Check the first few rows of the DataFrame (Optional for debugging)
print(df.head())

# Ensure columns are correctly typed (important for the callback)
df['Temperature'] = pd.to_numeric(df['Temperature'], errors='coerce')
df['sales_amount'] = pd.to_numeric(df['sales_amount'], errors='coerce')

# Initialize the Dash app with Plotly.js included to avoid timeout issues
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# App layout
app.layout = html.Div([
    html.H1("Sales and Weather Data Analysis", style={'text-align': 'center'}),

    # Date picker range to filter the data
    dcc.DatePickerRange(
        id='date-picker-range',
        start_date=df['date'].min().date(),
        end_date=df['date'].max().date(),
        display_format='YYYY-MM-DD',
        style={'margin': '20px'}
    ),

    # Dropdown to select the store location
    dcc.Dropdown(
        id='store-location-dropdown',
        options=[{'label': location, 'value': location} for location in df['store_location'].unique()],
        value='New York',
        style={'margin': '20px'}
    ),

    # Graph showing sales and weather analysis
    dcc.Graph(id='sales-weather-graph'),

    # Additional analysis (e.g., Humidity vs Sales)
    dcc.Graph(id='humidity-sales-graph')
])

# Callback to update graph based on selected date range and store location
@app.callback(
    [Output('sales-weather-graph', 'figure'),
     Output('humidity-sales-graph', 'figure')],
    [Input('date-picker-range', 'start_date'),
     Input('date-picker-range', 'end_date'),
     Input('store-location-dropdown', 'value')]
)
def update_graph(start_date, end_date, selected_location):
    # Filter the data based on user inputs
    filtered_df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]  # Use 'date' column
    filtered_df = filtered_df[filtered_df['store_location'] == selected_location]

    # Create the first figure: Sales vs Temperature
    sales_weather_fig = px.scatter(filtered_df, x='Temperature', y='sales_amount', color='product_id',
                                   labels={'Temperature': 'Temperature (°C)', 'sales_amount': 'Sales Amount ($)'},
                                   title=f'Sales Amount vs Temperature for {selected_location}')

    # Create the second figure: Humidity vs Sales
    humidity_sales_fig = px.scatter(filtered_df, x='Humidity', y='sales_amount', color='product_id',
                                    labels={'Humidity': 'Humidity (%)', 'sales_amount': 'Sales Amount ($)'},
                                    title=f'Sales Amount vs Humidity for {selected_location}')

    return sales_weather_fig, humidity_sales_fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ...
#                         _id       date product_id  sales_amount  \
# 0  67a85f9c67305126f1f96a62 2025-02-05       P001           150
# 1  67a85f9c67305126f1f96a63 2025-02-05       P002           300
# 2  67a85f9c67305126f1f96a64 2025-02-05       P003           450
# 3  67a85f9c67305126f1f96a65 2025-02-05       P004           600
# 4  67a85f9c67305126f1f96a66 2025-02-05       P005           750
#
#   store_location  Temperature  Humidity Weather_Description
# 0       New York         0.26        94          light rain
# 1    Los Angeles        11.27        82           clear sky
# 2        Chicago        -2.09        82       broken clouds
# 3        Houston        22.42        85     overcast clouds
# 4        Seattle         2.12        92                mist
